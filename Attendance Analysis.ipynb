# %% [markdown]
# ### Data Cleaning

# %%
# import libraries
import numpy as np
import pandas as pd
import glob
import os

# %%
# read, combine, and clean csv files
attendance_dir = "Attendance Data"
files = glob.glob(os.path.join(attendance_dir, "*.csv"))
columnsNeeded = ["First Name", "Last Name", "Email", "Account Type", "Year of Graduation", "Is Member", "Degree", "Registration Date", "Checked-In Date", "Attendee's Rating", "Attendee's Feedback", "Net ID"]
df_list = []

# read files
for file in files:
    fileName = os.path.basename(file).replace(".csv", "")
    try:
        df = pd.read_csv(file, usecols=columnsNeeded) # remove unnecessary columns
    except ValueError as e: # if a column needed isn't found
        print(f"Warning: {fileName} does not contain all specified columns. Skipping missing ones.")
        df = pd.read_csv(file)
        df = df[df.columns.intersection(columnsNeeded)]

    # update individual event data after cleaning
    df.to_csv(os.path.join(attendance_dir, f"{fileName}.csv"), index=False)

    # add event name column before combining dataset
    df["Event Name"] = fileName
    df_list.append(df)

df = pd.concat(df_list, ignore_index=True)
df.head()
# Out:
#     First Name   Last Name                Email           Account Type  \
# 0      Kernell       Slack       kslack@smu.edu  Undergraduate Student
# 1    ShyAnte'e    Williams    shyanteew@smu.edu                  Staff
# 2  Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# 3  Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# 4  Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
#
#   Year of Graduation Is Member                                Degree  \
# 0               2027        No             UG Cox School of Business
# 1            Unknown       Yes  Master's of Arts in Higher Education
# 2               2025        No                         Law - Masters
# 3               2025        No                         Law - Masters
# 4               2025        No                         Law - Masters
#
#         Registration Date         Checked-In Date  Attendee's Rating  \
# 0  10/25/2024 10:22:29 AM   10/26/2024 6:07:52 PM                NaN
# 1   10/25/2024 4:17:10 PM   10/26/2024 7:06:12 PM                NaN
# 2   10/25/2024 8:44:31 PM  10/26/2024 11:35:44 PM                NaN
# 3   10/25/2024 8:44:31 PM  10/26/2024 11:35:46 PM                NaN
# 4   10/25/2024 8:44:31 PM  10/26/2024 11:35:47 PM                NaN
#
#   Attendee's Feedback            Net ID Event Name
# 0                 NaN  49205773@smu.edu    Boaz WP
# 1                 NaN  46798462@smu.edu    Boaz WP
# 2                 NaN  49578809@smu.edu    Boaz WP
# 3                 NaN  49578809@smu.edu    Boaz WP
# 4                 NaN  49578809@smu.edu    Boaz WP

# %%
# Lots of duplicates but these are kept due to these signifying that attendees brought guests
df[df.duplicated(keep=False)]
# Out:
#      First Name Last Name              Email           Account Type  \
# 76       Kaylee   Dorough   kdorough@smu.edu  Undergraduate Student
# 77       Kaylee   Dorough   kdorough@smu.edu  Undergraduate Student
# 78       Kaylee   Dorough   kdorough@smu.edu  Undergraduate Student
# 79       Kaylee   Dorough   kdorough@smu.edu  Undergraduate Student
# 132      Brenda      Park     blpark@smu.edu                  Staff
# ...         ...       ...                ...                    ...
# 2127        Ali   Rasheed  akrasheed@smu.edu  Undergraduate Student
# 2238     Jialin       Yao    jialiny@smu.edu       Graduate Student
# 2239     Jialin       Yao    jialiny@smu.edu       Graduate Student
# 2461       Ayan      Khan      ayank@smu.edu  Undergraduate Student
# 2462       Ayan      Khan      ayank@smu.edu  Undergraduate Student
#
#      Year of Graduation Is Member                     Degree  \
# 76                 2025       Yes  UG Cox School of Business
# 77                 2025       Yes  UG Cox School of Business
# 78                 2025       Yes  UG Cox School of Business
# 79                 2025       Yes  UG Cox School of Business
# 132             Unknown        No                        NaN
# ...                 ...       ...                        ...
# 2127               2027        No             SMU Pre-Majors
# 2238               2025        No     Music - Artist Diploma
# 2239               2025        No     Music - Artist Diploma
# 2461               2026       Yes  UG Cox School of Business
# 2462               2026       Yes  UG Cox School of Business
#
#            Registration Date         Checked-In Date  Attendee's Rating  \
# 76     10/26/2024 7:04:11 PM   10/26/2024 7:04:11 PM                NaN
# 77     10/26/2024 7:04:11 PM   10/26/2024 7:04:11 PM                NaN
# 78     10/26/2024 7:04:11 PM   10/26/2024 7:04:11 PM                NaN
# 79     10/26/2024 7:04:11 PM   10/26/2024 7:04:11 PM                NaN
# 132    8/23/2024 11:02:55 AM                     NaN                NaN
# ...                      ...                     ...                ...
# 2127  10/23/2024 10:41:05 PM  10/23/2024 10:41:06 PM                NaN
# 2238  10/23/2024 11:36:49 PM  10/23/2024 11:36:49 PM                NaN
# 2239  10/23/2024 11:36:49 PM  10/23/2024 11:36:49 PM                NaN
# 2461   10/19/2024 6:52:48 PM   10/19/2024 8:22:03 PM                NaN
# 2462   10/19/2024 6:52:48 PM   10/19/2024 8:22:03 PM                NaN
#
#      Attendee's Feedback            Net ID       Event Name
# 76                   NaN  48571268@smu.edu          Boaz WP
# 77                   NaN  48571268@smu.edu          Boaz WP
# 78                   NaN  48571268@smu.edu          Boaz WP
# 79                   NaN  48571268@smu.edu          Boaz WP
# 132                  NaN  46687398@smu.edu           Comedy
# ...                  ...               ...              ...
# 2127                 NaN  49729986@smu.edu  Midnight Market
# 2238                 NaN  49356105@smu.edu  Midnight Market
# 2239                 NaN  49356105@smu.edu  Midnight Market
# 2461                 NaN  48874272@smu.edu      Stanford WP
# 2462                 NaN  48874272@smu.edu      Stanford WP
#
# [75 rows x 13 columns]

# %%
# number of missing values in each column
print(df.isna().sum())
# Out:
# First Name                5
# Last Name                 5
# Email                     0
# Account Type              0
# Year of Graduation        0
# Is Member                 0
# Degree                   94
# Registration Date         0
# Checked-In Date          54
# Attendee's Rating      2789
# Attendee's Feedback    2852
# Net ID                   34
# Event Name                0
# dtype: int64

# %%
# handles missing degree values
df["Degree"] = df["Degree"].fillna("Unknown")

# handles missing check-in dates
df["Checked-In Date"] = df["Checked-In Date"].fillna("No show")

# calculates avg ratings
avgRatings = df.groupby("Event Name")["Attendee's Rating"].mean()

# handles missing rating values
df["Attendee's Rating"] = df["Attendee's Rating"].fillna(df["Event Name"].map(avgRatings))

# handles missing feedback
df["Attendee's Feedback"] = df["Attendee's Feedback"].fillna("N/A")

# rename undergrad schools
df["Degree"] = df["Degree"].replace({"SMU Pre-Majors":"Pre-Majors", "Dedman College":"Dedman", "UG Cox School of Business":"Cox", "UG School of Engr & Appl Sci":"Lyle", "UG Meadows School of the Arts":"Meadows","Simmons School - Undergraduate":"Simmons"})

df
# Out:
#        First Name   Last Name                Email           Account Type  \
# 0         Kernell       Slack       kslack@smu.edu  Undergraduate Student
# 1       ShyAnte'e    Williams    shyanteew@smu.edu                  Staff
# 2     Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# 3     Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# 4     Abdulmohsen  Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# ...           ...         ...                  ...                    ...
# 2873      Tristan      Deters      tdeters@smu.edu  Undergraduate Student
# 2874        Kitty         Eid         keid@smu.edu  Undergraduate Student
# 2875     Daniella  Jerez Yada       djerez@smu.edu  Undergraduate Student
# 2876        Jacob        Roco        jroco@smu.edu  Undergraduate Student
# 2877      Melanie       Verdi       mverdi@smu.edu  Undergraduate Student
#
#      Year of Graduation Is Member                                Degree  \
# 0                  2027        No                                   Cox
# 1               Unknown       Yes  Master's of Arts in Higher Education
# 2                  2025        No                         Law - Masters
# 3                  2025        No                         Law - Masters
# 4                  2025        No                         Law - Masters
# ...                 ...       ...                                   ...
# 2873               2027       Yes                                   Cox
# 2874               2027        No                                Dedman
# 2875               2027        No                                   Cox
# 2876               2027        No                               Meadows
# 2877               2026        No                                Dedman
#
#            Registration Date         Checked-In Date  Attendee's Rating  \
# 0     10/25/2024 10:22:29 AM   10/26/2024 6:07:52 PM                5.0
# 1      10/25/2024 4:17:10 PM   10/26/2024 7:06:12 PM                5.0
# 2      10/25/2024 8:44:31 PM  10/26/2024 11:35:44 PM                5.0
# 3      10/25/2024 8:44:31 PM  10/26/2024 11:35:46 PM                5.0
# 4      10/25/2024 8:44:31 PM  10/26/2024 11:35:47 PM                5.0
# ...                      ...                     ...                ...
# 2873    4/18/2024 7:06:45 PM                 No show                5.0
# 2874    4/18/2024 7:29:43 PM    4/18/2024 7:29:43 PM                5.0
# 2875    4/18/2024 7:30:06 PM    4/18/2024 7:30:06 PM                5.0
# 2876    4/18/2024 7:30:36 PM    4/18/2024 7:30:36 PM                5.0
# 2877    4/18/2024 5:32:03 PM    4/18/2024 5:32:03 PM                5.0
#
#                                     Attendee's Feedback            Net ID  \
# 0                                                   N/A  49205773@smu.edu
# 1                                                   N/A  46798462@smu.edu
# 2                                                   N/A  49578809@smu.edu
# 3                                                   N/A  49578809@smu.edu
# 4                                                   N/A  49578809@smu.edu
# ...                                                 ...               ...
# 2873                                                N/A  49212806@smu.edu
# 2874                                                N/A  49136535@smu.edu
# 2875                                                N/A  49272827@smu.edu
# 2876                                                N/A  49190927@smu.edu
# 2877  Great! Options for vegetarians and delicious f...  48931511@smu.edu
#
#           Event Name
# 0            Boaz WP
# 1            Boaz WP
# 2            Boaz WP
# 3            Boaz WP
# 4            Boaz WP
# ...              ...
# 2873  Summer Sendoff
# 2874  Summer Sendoff
# 2875  Summer Sendoff
# 2876  Summer Sendoff
# 2877  Summer Sendoff
#
# [2878 rows x 13 columns]

# %%
df.to_csv("attendance2024.csv", index=False)

# %% [markdown]
# ### Unique Attendees

# %%
uniqueDF = df.drop(columns=["Event Name","Attendee's Rating","Attendee's Feedback","Registration Date","Checked-In Date"])
uniqueDF = uniqueDF.drop_duplicates(subset=["Email"])
uniqueDF.to_csv("uniqueAttendees2024.csv", index=False)
uniqueDF
# Out:
#        First Name    Last Name                Email           Account Type  \
# 0         Kernell        Slack       kslack@smu.edu  Undergraduate Student
# 1       ShyAnte'e     Williams    shyanteew@smu.edu                  Staff
# 2     Abdulmohsen   Alkhathlan  aalkhathlan@smu.edu       Graduate Student
# 5            Cara        Kilgo       ckilgo@smu.edu  Undergraduate Student
# 6        Isabella      Marotta     imarotta@smu.edu  Undergraduate Student
# ...           ...          ...                  ...                    ...
# 2865         Maya  Fardad-Finn  mfardadfinn@smu.edu  Undergraduate Student
# 2868       Alonso      Gurrola     agurrola@smu.edu  Undergraduate Student
# 2870       Taylor      Kimball     tkimball@smu.edu  Undergraduate Student
# 2874        Kitty          Eid         keid@smu.edu  Undergraduate Student
# 2875     Daniella   Jerez Yada       djerez@smu.edu  Undergraduate Student
#
#      Year of Graduation Is Member                                Degree  \
# 0                  2027        No                                   Cox
# 1               Unknown       Yes  Master's of Arts in Higher Education
# 2                  2025        No                         Law - Masters
# 5                  2028        No                            Pre-Majors
# 6                  2028        No                            Pre-Majors
# ...                 ...       ...                                   ...
# 2865               2025        No                               Meadows
# 2868               2026        No                                  Lyle
# 2870               2025        No                                Dedman
# 2874               2027        No                                Dedman
# 2875               2027        No                                   Cox
#
#                 Net ID
# 0     49205773@smu.edu
# 1     46798462@smu.edu
# 2     49578809@smu.edu
# 5     49438266@smu.edu
# 6     49426280@smu.edu
# ...                ...
# 2865  48515160@smu.edu
# 2868  48951856@smu.edu
# 2870  48572685@smu.edu
# 2874  49136535@smu.edu
# 2875  49272827@smu.edu
#
# [1806 rows x 8 columns]

# %%
undergradTotal = 7285
undergradAttendance = len(uniqueDF[uniqueDF["Account Type"] == "Undergraduate Student"])

undergradProp = undergradAttendance / undergradTotal
undergradProp
# Out:
# 0.20480439258750857
